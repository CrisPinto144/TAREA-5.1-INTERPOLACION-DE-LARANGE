# %%
#   Codigo que implementa la interpolacion de Lagrange
#   para ajustar un conjunto de datos
#
#
#           Autor:
#   Cristian Yuseff Pinto Villanueva
#   cristian.pino984@gmail.com
#   Version 1.0 : 01/04/2025
#
#   EJERCICIO 1

import numpy as np
import matplotlib.pyplot as plt

# Datos del ejercicio: posición (m) y deformación (mm)
x_points = np.array([0.5, 1.0, 1.5, 2.0])
y_points = np.array([1.2, 2.3, 3.7, 5.2])

# Función de interpolación de Lagrange
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Calcular la deformación en x = 1.25 m
x_eval = 1.25
deformacion_estimada = lagrange_interpolation(x_eval, x_points, y_points)
print(f"Deformación estimada en x = {x_eval} m: {deformacion_estimada:.4f} mm")

# b) Graficar la interpolación en el rango [0.5, 2.0]
x_values = np.linspace(0.5, 2.0, 200)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

# Graficar
plt.figure(figsize=(6,4))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Puntos dados")
plt.scatter(x_eval, deformacion_estimada, color="green", label=f"Estimación en x={x_eval}", zorder=5)
plt.xlabel("Posición (m)")
plt.ylabel("Deformación (mm)")
plt.title("Interpolación de Lagrange - Deformación en una Viga")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Deformación estimada en x = 1.25 m: 2.9750 mm

# %%
#  EJERCICIOO 2

import numpy as np
import matplotlib.pyplot as plt

# Datos del ejercicio: posición (m) y deformación (mm)
x_points = np.array([1.0, 2.5, 4.0, 5.5])
y_points = np.array([85, 78, 69, 60])

# Función de interpolación de Lagrange
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Calcular la estimacion de la temperatura de un motor en x = 3.0 cm
x_eval = 3.0
deformacion_estimada = lagrange_interpolation(x_eval, x_points, y_points)
print(f"Temperatura a una profundidad de x = {x_eval} cm: {deformacion_estimada:.4f} °C")

# b) Graficar la interpolación en el rango [1.0, 5.5]
x_values = np.linspace(1.0, 5.5, 200)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

# Graficar
plt.figure(figsize=(6,4))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Puntos dados")
plt.scatter(x_eval, deformacion_estimada, color="green", label=f"Estimación en x={x_eval}", zorder=5)
plt.xlabel("Profundidad (cm)")
plt.ylabel("Temperatura (°C)")
plt.title("Interpolación de Lagrange - Estimación de la temperatura de un motor")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Temperatura a una profundidad de x = 3.0 cm: 75.1235 °C

# %%
# EJERCICIO 3

import numpy as np
import matplotlib.pyplot as plt

# Datos del ejercicio: posición (m) y deformación (mm)
x_points = np.array([2.0, 4.0, 6.0, 8.0])
y_points = np.array([2500, 2300, 2150, 2050])

# Función de interpolación de Lagrange
def lagrange_interpolation(x, x_points, y_points):
    n = len(x_points)
    result = 0
    for i in range(n):
        term = y_points[i]
        for j in range(n):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# a) Calcular consumo de combustible en x = 5 km
x_eval = 5
deformacion_estimada = lagrange_interpolation(x_eval, x_points, y_points)
print(f"Consumo de combustible a una altitud de x = {x_eval} km: {deformacion_estimada:.4f} kg/h")

# b) Graficar la interpolación en el rango [2.0, 8.0]
x_values = np.linspace(2.0, 8.0, 200)
y_values = [lagrange_interpolation(x, x_points, y_points) for x in x_values]

# Graficar
plt.figure(figsize=(6,4))
plt.plot(x_values, y_values, label="Interpolación de Lagrange", color="blue")
plt.scatter(x_points, y_points, color="red", label="Puntos dados")
plt.scatter(x_eval, deformacion_estimada, color="green", label=f"Estimación en x={x_eval}", zorder=5)
plt.xlabel("Altitud (km)")
plt.ylabel("Consumo (kg/h)")
plt.title("Interpolación de Lagrange - Predicción del consumo de combustible en Aeronaves")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Consumo de combustible a una altitud de x = 5 km: 2218.7500 kg/h
